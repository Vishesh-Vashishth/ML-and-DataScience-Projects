# %% [markdown]
# ### Simple linear regression is a statistical method that allows us to summarize and study relationships between two continuous (quantitative) variables:
#
# ### One variable, denoted x, is regarded as the predictor, explanatory, or independent variable.
# ### The other variable, denoted y, is regarded as the response, outcome, or dependent variable.

# %% [markdown]
# ### Linear Equation y = ax+b , a = slope/coffiecient  b= intercept/constant

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline      #The line magic command %matplotlib inline enables the drawing of matplotlib figures in the IPython environment. Once this command is executed in any cell, the matplotlib plots will appear directly below the cell in which the plot function was called for the rest of the session.
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9292\2225940201.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = [[1, 10000], [2, 15000], [3, 19000],[4, 25000], [5,31000],[6,38000], [7,42000], [8,50000], [9,53000], [10,60000]]

# %%
df = pd.DataFrame(data, columns=['Experience', 'Salary'])

# %%
df
# Out:
#    Experience  Salary
# 0           1   10000
# 1           2   15000
# 2           3   19000
# 3           4   25000
# 4           5   31000
# 5           6   38000
# 6           7   42000
# 7           8   50000
# 8           9   53000
# 9          10   60000

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.6 kB 330.3 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.6 kB 440.4 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 292.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 640.0 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/10.6 MB 787.7 kB/s eta 0:00:14
#    ---------------------------------------- 0.1/10.6 MB 901.1 kB/s eta 0:00:12
#     --------------------------------------- 0.2/10.6 MB 1.0 MB/s eta 0:00:10
#     --------------------------------------- 0.2/10.6 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.3/10.6 MB 983.0 kB/s eta 0:00:11
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()      #creating linear regression obkect
model.fit(df[['Experience']] , df['Salary'])    #we have to put the value of x in 2d array
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()      #creating linear regression obkect
model.fit(df[['Experience']] , df['Salary'])
# Out:
# LinearRegression()

# %% [markdown]
# ## Start making Predcirtion

# %%
model.predict([[5]])     #we have to put the value of x in 2d array
# Out:
# C:\Users\HP\miniconda3\envs\pydata-book\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31484.84848485])

# %%
model.predict([[17]])
# Out:
# C:\Users\HP\miniconda3\envs\pydata-book\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([99048.48484848])

# %%
model.score(df[['Experience']] , df['Salary'])    #to check the accuracy of model
# Out:
# 0.9966372308889744

# %%
model.coef_    #checking the coffecient(m)
# Out:
# array([5630.3030303])

# %%
model.intercept_
# Out:
# 3333.3333333333285

# %%
# checking y from the equatiobn y=mx+b
y = (5630.3030303*5)+3333.3333333333285

# %%
y
# Out:
# 31484.848484833325

# %%
plt.scatter(df['Experience'] , df['Salary'], color ='r' , marker= '*')

# %%
plt.plot(df['Experience'] , model.predict(df[['Experience']]) )

# %%
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(df['Experience'] , df['Salary'], color ='r' , marker= '*')
plt.plot(df['Experience'] , model.predict(df[['Experience']]) )
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')
