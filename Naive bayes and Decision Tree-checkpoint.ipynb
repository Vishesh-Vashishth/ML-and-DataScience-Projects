# %% [markdown]
# **Naive bayes**

# %%
#load dataset
from sklearn.datasets import load_iris

# %%
X,y = load_iris(return_X_y= True, as_frame= True)

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2529, stratify=y)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.86      1.00      0.92        12
#            2       1.00      0.85      0.92        13
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.95      0.95        38
# weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# **Decision tree**

# %%
from sklearn.tree import DecisionTreeClassifier , plot_tree

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.86      1.00      0.92        12
#            2       1.00      0.85      0.92        13
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.95      0.95        38
# weighted avg       0.95      0.95      0.95        38

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()

# %%
plot_tree(dtc, feature_names = X.columns)
# Out:
# [Text(0.3333333333333333, 0.9285714285714286, 'petal width (cm) <= 0.7\ngini = 0.667\nsamples = 112\nvalue = [37, 38, 37]'),
#  Text(0.2222222222222222, 0.7857142857142857, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]'),
#  Text(0.4444444444444444, 0.7857142857142857, 'petal width (cm) <= 1.65\ngini = 0.5\nsamples = 75\nvalue = [0, 38, 37]'),
#  Text(0.2222222222222222, 0.6428571428571429, 'petal length (cm) <= 5.25\ngini = 0.053\nsamples = 37\nvalue = [0, 36, 1]'),
#  Text(0.1111111111111111, 0.5, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(0.3333333333333333, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.6428571428571429, 'petal length (cm) <= 5.05\ngini = 0.1\nsamples = 38\nvalue = [0, 2, 36]'),
#  Text(0.5555555555555556, 0.5, 'sepal width (cm) <= 2.9\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5]'),
#  Text(0.4444444444444444, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.6666666666666666, 0.35714285714285715, 'sepal length (cm) <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.5555555555555556, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7777777777777778, 0.21428571428571427, 'petal length (cm) <= 4.9\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.6666666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8888888888888888, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7777777777777778, 0.5, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]
